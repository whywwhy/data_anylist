# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import numpy as np

# %%
df_incruit = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/incruit_result.csv')
df_incruit2 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/incruit_result2.csv')
df_jobkorea = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/resultJobkorea.csv')
df_jobkorea2 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/resultJobkorea2.csv')
df_jobkorea3 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/resultJobkorea3.csv')
df_saramin = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/saramin_result.csv')
df_saramin2 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/saramin_result2.csv')

# %%
df_incruit.head()
# Out:
#             회사명                          공고명         경력    학력      지역  고용형태  \
# 0  주식회사 더쇼소프트웨어           게임 프론트엔드 개발자 채용 공고      5~99년  학력무관  서울>강남구   정규직
# 1           시스루  웹 시스템 유지보수 프론트엔드/백엔드 개발자 채용        3년↑  학력무관  서울>용산구   정규직
# 2         프리것버드            프론트엔드 개발자 모집(팀장급)        5년↑  학력무관    서울 외   정규직
# 3          비브이씨            비브이씨 프론트엔드 개발자 모집  신입/(연차무관)  학력무관  서울>마포구   정규직
# 4          딥세일즈              프론트엔드개발자 (5년이상)        5년↑  대졸이상  서울>강남구  정규직외
#
#     연봉                                              직무 분야 마감 기한  \
# 0  NaN  웹프로그래머, HTML·퍼블리싱·UI개발, 웹디자인, 웹기획·웹마케팅·PM, 네트워...   채용시
# 1  NaN                             웹프로그래머, HTML·퍼블리싱·UI개발   채용시
# 2  NaN                                             웹프로그래머    상시
# 3   월급                                 웹프로그래머, 소프트웨어·하드웨어    상시
# 4  NaN                                             웹프로그래머   채용시
#
#                                                공고 링크
# 0  https://job.incruit.com/jobdb_info/jobpost.asp...
# 1  https://job.incruit.com/jobdb_info/jobpost.asp...
# 2  https://job.incruit.com/jobdb_info/jobpost.asp...
# 3  https://job.incruit.com/jobdb_info/jobpost.asp...
# 4  https://job.incruit.com/jobdb_info/jobpost.asp...

# %%
df_jobkorea.head()
# Out:
#           회사명                                                공고명  \
# 0      우아한형제들                                   각 부문별 경력/신입 인재영입
# 1  ㈜하이미디어아카데미            [전액무료IT개발자취업생모집]JAVA개발자/풀스택개발자/AI서비스개발자
# 2       ㈜세종교육  [IT취업률100프로]개발자 채용연계(국내/일본, 수도권무료숙식 제공/비전공자 가능...
# 3       빗썸코리아                                  2024 빗썸코리아 전직군 채용
# 4     ㈜엘엑스세미콘                           [LX세미콘] 2024년 9월 경력사원 채용
#
#   채용 형태(경력, 신입)    학력     직장 위치 마감 기한  \
# 0         신입·경력  학력무관    서울 송파구  상시채용
# 1         신입·경력  학력무관        서울  D-16
# 2         신입·경력  학력무관  서울 강남구 외  D-14
# 3          경력무관  학력무관  서울 강남구 외  상시채용
# 4         경력1년↑  학력무관  서울 서초구 외   D-5
#
#                                                공고 링크
# 0  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 1  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 2  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 3  https://www.jobkorea.co.kr/Recruit/GI_Read/455...
# 4  https://www.jobkorea.co.kr/Recruit/GI_Read/455...

# %%
df_saramin.head()
# Out:
#       회사명                             공고명    학력      지역  \
# 0  아주큐엠에스                        프론트엔드개발자  초대졸↑  서울 서초구
# 1   인파트너스  지식콘텐츠 전문기업(매출150억) 프론트엔드개발자 채용   대졸↑  서울 서초구
# 2   리비바이오                [리비바이오] 프론트엔드개발자  학력무관  서울 강남구
# 3    조베이스                 프론트엔드개발자 경력직 모집   대졸↑  서울 강남구
# 4    디카르고                        프론트엔드개발자  학력무관  서울 강남구
#
#                                                직무 분야       마감 기한  \
# 0  웹개발, 프론트엔드, ECMAScript, Javascript, React 외 등록...  ~ 10/05(토)
# 1     프론트엔드, 반응형웹, 웹표준·웹접근성, AWS, CSS 외 수정일 24/09/24  ~ 10/17(목)
# 2     프론트엔드, AWS, Git, GraphQL, React 외 수정일 24/09/11  ~ 11/08(금)
# 3  웹개발, Javascript, Node.js, React, ReactJS 외 수정일...  ~ 10/12(토)
# 4       프론트엔드, 블록체인, API, CSS, Docker 외 등록일 24/09/25        상시채용
#
#                                                공고 링크
# 0  https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 1  https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 2  https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 3  https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 4  https://www.saramin.co.kr/zf_user/jobs/relay/v...

# %%
from IPython.display import display

# %%
# 데이터 불러오기
df_incruit = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/incruit_result.csv')

# 필요한 열만 선택
df_selected_incruit = df_incruit[['회사명', '공고명', '학력', '경력', '지역', '공고 링크']]

# 데이터프레임 형태로 보기
display(df_selected_incruit)

# 선택한 열로 새로운 파일 저장
df_selected_incruit.to_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_incruit_result.csv', index=False)
# Out:
#                회사명                                                공고명    학력  \
# 0     주식회사 더쇼소프트웨어                                 게임 프론트엔드 개발자 채용 공고  학력무관
# 1              시스루                        웹 시스템 유지보수 프론트엔드/백엔드 개발자 채용  학력무관
# 2            프리것버드                                  프론트엔드 개발자 모집(팀장급)  학력무관
# 3             비브이씨                                  비브이씨 프론트엔드 개발자 모집  학력무관
# 4             딥세일즈                                    프론트엔드개발자 (5년이상)  대졸이상
# ..             ...                                                ...   ...
# 221  주식회사 소프트위드솔루션                                      웹개발 경력 정규직 채용  대졸이상
# 222       더팀엔터테인먼트         [일자리매칭플랫폼] [더팀엔터테인먼트] VR 유니티 신입 개발자를 모십니다.  학력무관
# 223         이스트게임즈  [ESTgames] 게임 서버 (툴/인프라) 개발자 (C#, .NET Core Bl...  학력무관
# 224        나이아가라관광          신입 및 경력직 사원, 대리, 팀장 -프런트 주야간 근무자 채용(~채용시)  학력무관
# 225            컴투스                [제노니아:크로노브레이크] 빌드 배포 담당 개발자 (단기계약직)  학력무관
#
#             경력      지역                                              공고 링크
# 0        5~99년  서울>강남구  https://job.incruit.com/jobdb_info/jobpost.asp...
# 1          3년↑  서울>용산구  https://job.incruit.com/jobdb_info/jobpost.asp...
# 2          5년↑    서울 외  https://job.incruit.com/jobdb_info/jobpost.asp...
# 3    신입/(연차무관)  서울>마포구  https://job.incruit.com/jobdb_info/jobpost.asp...
# 4          5년↑  서울>강남구  https://job.incruit.com/jobdb_info/jobpost.asp...
# ..         ...     ...                                                ...
# 221       5~9년  서울>강남구  https://job.incruit.com/jobdb_info/jobpost.asp...
# 222         신입  서울>마포구  https://job.incruit.com/jobdb_info/jobpost.asp...
# 223        3년↑  서울>서초구  https://job.incruit.com/jobdb_info/jobpost.asp...
# 224        1년↑  서울>강서구  https://job.incruit.com/jobdb_info/jobpost.asp...
# 225     (연차무관)  서울>금천구  https://job.incruit.com/jobdb_info/jobpost.asp...
#
# [226 rows x 6 columns]

# %%
# 데이터 불러오기
df_incruit2 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/incruit_result2.csv')

# 필요한 열만 선택
df_selected_incruit2 = df_incruit2[['회사명', '공고명', '학력', '경력', '지역', '공고 링크']]

# 데이터프레임 형태로 보기
display(df_selected_incruit2)

# 선택한 열로 새로운 파일 저장
df_selected_incruit2.to_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_incruit_result2.csv', index=False)
# Out:
#             회사명                                                공고명     학력  \
# 0        에이피서비스                                자바 웹개발자 채용(백엔드 개발자)   학력무관
# 1           코이노                        [경력]웹개발자, JavaScript, Vu.js   대졸이상
# 2          디비비전                                      웹개발 경력자 모집합니다  초대졸이상
# 3        다올앤컴퍼니                                     웹 앱 개발자 모집합니다.   학력무관
# 4        엑스오소프트                           WEB개발(JAVA) 경력 개발자 모십니다.   학력무관
# ..          ...                                                ...    ...
# 248         세스코                                        사내교육 개발, 운영   대졸이상
# 249         카이어                          인공지능 솔루션 (AI Solution) 개발  초대졸이상
# 250   신우에프에이이십일                                  자동 제어 시스템 프로그램 개발   학력무관
# 251         가오콘  마곡본사&마곡LG에서 차량용 AVN개발, 캠핑카 레저 IT개발, 셋톱박스,OTT 경...   학력무관
# 252  엣지에너지 주식회사                                  연구소,사업개발 신입/경력 채용   학력무관
#
#             경력      지역                                              공고 링크
# 0        4~10년  서울>강남구  https://job.incruit.com/jobdb_info/jobpost.asp...
# 1          3년↑  서울>강서구  https://job.incruit.com/jobdb_info/jobpost.asp...
# 2        6~10년  서울>금천구  https://job.incruit.com/jobdb_info/jobpost.asp...
# 3           신입  서울>강서구  https://job.incruit.com/jobdb_info/jobpost.asp...
# 4          2년↑  서울>마포구  https://job.incruit.com/jobdb_info/jobpost.asp...
# ..         ...     ...                                                ...
# 248        2년↑  서울>강동구  https://job.incruit.com/jobdb_info/jobpost.asp...
# 249   신입/10년미만  서울>서초구  https://job.incruit.com/jobdb_info/jobpost.asp...
# 250  신입/(연차무관)  서울>금천구  https://job.incruit.com/jobdb_info/jobpost.asp...
# 251        5년↑  서울>강서구  https://job.incruit.com/jobdb_info/jobpost.asp...
# 252  신입/(연차무관)  서울>강서구  https://job.incruit.com/jobdb_info/jobpost.asp...
#
# [253 rows x 6 columns]

# %%
import pandas as pd
from IPython.display import display

# 데이터 불러오기
df_jobkorea = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/resultJobkorea.csv')

# 열 이름 변경 (혹시 모를 공백 제거)
df_jobkorea.columns = df_jobkorea.columns.str.strip()

# 열 이름 변경
df_jobkorea_renamed = df_jobkorea.rename(columns={
    '채용 형태(경력, 신입)': '경력',
    '직장 위치': '지역'
})

# 빈 문자열을 NaN으로 변환
df_jobkorea_renamed = df_jobkorea_renamed.replace('', pd.NA)

# '공고 링크' 열을 제외한 모든 열이 NaN인 행을 제거
df_jobkorea_cleaned = df_jobkorea_renamed.dropna(subset=['회사명', '공고명', '학력', '경력', '지역'], how='all')

# 결과 확인 (데이터프레임 형태로 출력)
display(df_jobkorea_cleaned.head())

# 필요한 열만 선택
df_selected_jobkorea = df_jobkorea_cleaned[['회사명', '공고명', '학력', '경력', '지역', '공고 링크']]

# 데이터프레임 형태로 보기
display(df_selected_jobkorea)

# 선택한 열로 새로운 파일 저장
df_selected_jobkorea.to_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_jobkorea_result.csv', index=False)
# Out:
#           회사명                                                공고명     경력    학력  \
# 0      우아한형제들                                   각 부문별 경력/신입 인재영입  신입·경력  학력무관
# 1  ㈜하이미디어아카데미            [전액무료IT개발자취업생모집]JAVA개발자/풀스택개발자/AI서비스개발자  신입·경력  학력무관
# 2       ㈜세종교육  [IT취업률100프로]개발자 채용연계(국내/일본, 수도권무료숙식 제공/비전공자 가능...  신입·경력  학력무관
# 3       빗썸코리아                                  2024 빗썸코리아 전직군 채용   경력무관  학력무관
# 4     ㈜엘엑스세미콘                           [LX세미콘] 2024년 9월 경력사원 채용  경력1년↑  학력무관
#
#          지역 마감 기한                                              공고 링크
# 0    서울 송파구  상시채용  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 1        서울  D-16  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 2  서울 강남구 외  D-14  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 3  서울 강남구 외  상시채용  https://www.jobkorea.co.kr/Recruit/GI_Read/455...
# 4  서울 서초구 외   D-5  https://www.jobkorea.co.kr/Recruit/GI_Read/455...
#              회사명                                                공고명    학력  \
# 0         우아한형제들                                   각 부문별 경력/신입 인재영입  학력무관
# 1     ㈜하이미디어아카데미            [전액무료IT개발자취업생모집]JAVA개발자/풀스택개발자/AI서비스개발자  학력무관
# 2          ㈜세종교육  [IT취업률100프로]개발자 채용연계(국내/일본, 수도권무료숙식 제공/비전공자 가능...  학력무관
# 3          빗썸코리아                                  2024 빗썸코리아 전직군 채용  학력무관
# 4        ㈜엘엑스세미콘                           [LX세미콘] 2024년 9월 경력사원 채용  학력무관
# ...          ...                                                ...   ...
# 2337    ㈜더에스엠씨그룹         [The SMC] AE/퍼포먼스마케터/모션그래퍼 등 마케팅 부문별 인재 영입  학력무관
# 2338      모티바코리아                                      인사총무 경력직(팀장급)  학력무관
# 2339      디에이엠에스                    [인사관리]경력무관/신입환영/[주5일제/정규직/중식제공]  학력무관
# 2340       비플라넷㈜                                인사 및 경영지원 담당 정규직 채용   대졸↑
# 2341       ㈜디에이피                     디에이피 안성공장 2024년 하반기 채용(기숙사 있음)  학력무관
#
#          경력        지역                                              공고 링크
# 0     신입·경력    서울 송파구  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 1     신입·경력        서울  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 2     신입·경력  서울 강남구 외  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 3      경력무관  서울 강남구 외  https://www.jobkorea.co.kr/Recruit/GI_Read/455...
# 4     경력1년↑  서울 서초구 외  https://www.jobkorea.co.kr/Recruit/GI_Read/455...
# ...     ...       ...                                                ...
# 2337  신입·경력        서울  https://www.jobkorea.co.kr/Recruit/GI_Read/454...
# 2338     경력        서울  https://www.jobkorea.co.kr/Recruit/GI_Read/455...
# 2339   경력무관      인천 외  https://www.jobkorea.co.kr/Recruit/GI_Read/455...
# 2340  신입·경력      서울 외  https://www.jobkorea.co.kr/Recruit/GI_Read/454...
# 2341  신입·경력        경기  https://www.jobkorea.co.kr/Recruit/GI_Read/455...
#
# [1492 rows x 6 columns]

# %%
import pandas as pd
from IPython.display import display

# 데이터 불러오기
df_jobkorea2 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/resultJobkorea2.csv')

# 열 이름 변경 (혹시 모를 공백 제거)
df_jobkorea2.columns = df_jobkorea2.columns.str.strip()

# 열 이름 변경
df_jobkorea2_renamed = df_jobkorea2.rename(columns={
    '채용 형태(경력, 신입)': '경력',
    '직장 위치': '지역'
})

# 빈 문자열을 NaN으로 변환
df_jobkorea2 = df_jobkorea2_renamed.replace('', pd.NA)

# '공고 링크' 열을 제외한 모든 열이 NaN인 행을 제거
df_jobkorea_cleaned2 = df_jobkorea2_renamed.dropna(subset=['회사명', '공고명', '학력', '경력', '지역'], how='all')

# 결과 확인 (데이터프레임 형태로 출력)
display(df_jobkorea_cleaned2.head())

# 필요한 열만 선택
df_selected_jobkorea2 = df_jobkorea_cleaned2[['회사명', '공고명', '학력', '경력', '지역', '공고 링크']]

# 데이터프레임 형태로 보기
display(df_selected_jobkorea2)

# 선택한 열로 새로운 파일 저장
df_selected_jobkorea2.to_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_jobkorea_result2.csv', index=False)
# Out:
#           회사명                                                공고명     경력    학력  \
# 0      우아한형제들                                   각 부문별 경력/신입 인재영입  신입·경력  학력무관
# 1  ㈜하이미디어아카데미            [전액무료IT개발자취업생모집]JAVA개발자/풀스택개발자/AI서비스개발자  신입·경력  학력무관
# 2       ㈜세종교육  [IT취업률100프로]개발자 채용연계(국내/일본, 수도권무료숙식 제공/비전공자 가능...  신입·경력  학력무관
# 3        ㈜비알팜  홍보마케팅/전시기획/해외영업/국내영업/영업관리/해외 인허가/기업부설 연구소/온라인M...  경력2년↑  학력무관
# 4          CJ                                 2024년 CJ그룹 신입사원 모집     신입   대졸↑
#
#          지역 마감 기한                                              공고 링크
# 0    서울 송파구  상시채용  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 1        서울  D-15  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 2  서울 강남구 외  D-13  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 3  서울 송파구 외  상시채용  https://www.jobkorea.co.kr/Recruit/GI_Read/455...
# 4   서울 중구 외   D-8  https://www.jobkorea.co.kr/Recruit/GI_Read/455...
#                회사명                                                공고명    학력  \
# 0           우아한형제들                                   각 부문별 경력/신입 인재영입  학력무관
# 1       ㈜하이미디어아카데미            [전액무료IT개발자취업생모집]JAVA개발자/풀스택개발자/AI서비스개발자  학력무관
# 2            ㈜세종교육  [IT취업률100프로]개발자 채용연계(국내/일본, 수도권무료숙식 제공/비전공자 가능...  학력무관
# 3             ㈜비알팜  홍보마케팅/전시기획/해외영업/국내영업/영업관리/해외 인허가/기업부설 연구소/온라인M...  학력무관
# 4               CJ                                 2024년 CJ그룹 신입사원 모집   대졸↑
# ...            ...                                                ...   ...
# 3812          벤처기업                     [가산] 제조 AI 솔루션 아기유니콘 프론트엔드 개발자   대졸↑
# 3813  중견기업(300명이상)            프로젝트 PM (SaaS, 클라우드, AI 분야에 대한 이해도가 필수)   대졸↑
# 3814  중소기업(300명이하)                         [코스닥 상장사] Project PM 경력 모집   대졸↑
# 3815  중소기업(300명이하)                  [국내최대 가상자산거래소기업] UX/UI 디자이너 [정규직]  초대졸↑
# 3816   대기업 계열사·자회사  [제안] 영어교육 콘텐츠 개발사(그룹사) - 플랫폼 Product Owner (실장...   대졸↑
#
#           경력        지역                                              공고 링크
# 0      신입·경력    서울 송파구  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 1      신입·경력        서울  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 2      신입·경력  서울 강남구 외  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 3      경력2년↑  서울 송파구 외  https://www.jobkorea.co.kr/Recruit/GI_Read/455...
# 4         신입   서울 중구 외  https://www.jobkorea.co.kr/Recruit/GI_Read/455...
# ...      ...       ...                                                ...
# 3812   경력2년↑    서울 금천구  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 3813   경력7년↑    서울 전지역  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 3814   경력7년↑    서울 서초구  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 3815   경력4년↑    서울 강남구  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 3816  경력12년↑    서울 서초구  https://www.jobkorea.co.kr/Recruit/GI_Read/452...
#
# [2549 rows x 6 columns]

# %%
import pandas as pd
from IPython.display import display

# 데이터 불러오기
df_jobkorea3 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/resultJobkorea3.csv')

# 열 이름 변경 (혹시 모를 공백 제거)
df_jobkorea3.columns = df_jobkorea3.columns.str.strip()

# 열 이름 변경
df_jobkorea3_renamed = df_jobkorea3.rename(columns={
    '채용 형태(경력, 신입)': '경력',
    '직장 위치': '지역'
})

# 빈 문자열을 NaN으로 변환
df_jobkorea3 = df_jobkorea3_renamed.replace('', pd.NA)

# '공고 링크' 열을 제외한 모든 열이 NaN인 행을 제거
df_jobkorea_cleaned3 = df_jobkorea3_renamed.dropna(subset=['회사명', '공고명', '학력', '경력', '지역'], how='all')

# 결과 확인 (데이터프레임 형태로 출력)
display(df_jobkorea_cleaned3.head())

# 필요한 열만 선택
df_selected_jobkorea3 = df_jobkorea_cleaned3[['회사명', '공고명', '학력', '경력', '지역', '공고 링크']]

# 데이터프레임 형태로 보기
display(df_selected_jobkorea3)

# 선택한 열로 새로운 파일 저장
df_selected_jobkorea3.to_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_jobkorea_result3.csv', index=False)
# Out:
#           회사명                                                공고명     경력    학력  \
# 0  ㈜하이미디어아카데미            [전액무료IT개발자취업생모집]JAVA개발자/풀스택개발자/AI서비스개발자  신입·경력  학력무관
# 1       ㈜세종교육  [IT취업률100프로]개발자 채용연계(국내/일본, 수도권무료숙식 제공/비전공자 가능...  신입·경력  학력무관
# 2        ㈜가비아                                2024년 가비아 하반기 신입 공채     신입   대졸↑
# 3     ㈜비즈테크아이      [LG CNS 자회사] 스마트팩토리 솔루션 서울/대전 Web 분석설계 경력직 채용  경력3년↑   대졸↑
# 4        ㈜다임즈                                      Web 개발 및 유지보수  경력3년↑  초대졸↑
#
#          지역 마감 기한                                              공고 링크
# 0        서울  D-15  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 1  서울 강남구 외  D-13  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 2  서울 금천구 외  D-17  https://www.jobkorea.co.kr/Recruit/GI_Read/455...
# 3  서울 강서구 외   D-4  https://www.jobkorea.co.kr/Recruit/GI_Read/454...
# 4    서울 동작구   D-3  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
#              회사명                                                공고명    학력  \
# 0     ㈜하이미디어아카데미            [전액무료IT개발자취업생모집]JAVA개발자/풀스택개발자/AI서비스개발자  학력무관
# 1          ㈜세종교육  [IT취업률100프로]개발자 채용연계(국내/일본, 수도권무료숙식 제공/비전공자 가능...  학력무관
# 2           ㈜가비아                                2024년 가비아 하반기 신입 공채   대졸↑
# 3        ㈜비즈테크아이      [LG CNS 자회사] 스마트팩토리 솔루션 서울/대전 Web 분석설계 경력직 채용   대졸↑
# 4           ㈜다임즈                                      Web 개발 및 유지보수  초대졸↑
# ...          ...                                                ...   ...
# 1106        ㈜에임드                               [웹3 개발팀] Web3 게임 기획자  학력무관
# 1107       루다게임즈                    Web3 G&E 플랫폼 PERPLAY 시스템 기획자 모집  학력무관
# 1108       루다게임즈                    Web3 G&E 플랫폼 PERPLAY 시스템 개발자 모집  학력무관
# 1109        크래프톤  [Publishing Platform Div.]Sr. Web Back-End Dev...  학력무관
# 1110        크래프톤  [Publishing Platform Div.] Web Service QA (3년 이상)  학력무관
#
#          경력        지역                                              공고 링크
# 0     신입·경력        서울  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 1     신입·경력  서울 강남구 외  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# 2        신입  서울 금천구 외  https://www.jobkorea.co.kr/Recruit/GI_Read/455...
# 3     경력3년↑  서울 강서구 외  https://www.jobkorea.co.kr/Recruit/GI_Read/454...
# 4     경력3년↑    서울 동작구  https://www.jobkorea.co.kr/Recruit/GI_Read/453...
# ...     ...       ...                                                ...
# 1106  경력1년↑    서울 서초구  https://www.gamejob.co.kr/List_GI/GIB_Read.asp...
# 1107  경력2년↑    서울 구로구  https://www.gamejob.co.kr/List_GI/GIB_Read.asp...
# 1108  신입·경력    서울 구로구  https://www.gamejob.co.kr/List_GI/GIB_Read.asp...
# 1109  경력5년↑    서울 강남구  https://www.gamejob.co.kr/List_GI/GIB_Read.asp...
# 1110  경력5년↑    서울 강남구  https://www.gamejob.co.kr/List_GI/GIB_Read.asp...
#
# [1101 rows x 6 columns]

# %%
import pandas as pd
from IPython.display import display

# 데이터 불러오기
df_saramin = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/saramin_result.csv')

# '경력' 열 추가 (빈 값으로 설정)
df_saramin['경력'] = pd.NA

# 필요한 열만 선택
df_selected_saramin = df_saramin[['회사명', '공고명', '학력', '경력', '지역', '공고 링크']]

# 데이터프레임 형태로 출력
display(df_selected_saramin)

# 선택한 열로 새로운 파일 저장
df_selected_saramin.to_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_saramin_result.csv', index=False)
# Out:
#             회사명                                   공고명    학력   경력      지역  \
# 0        아주큐엠에스                              프론트엔드개발자  초대졸↑  NaN  서울 서초구
# 1         인파트너스        지식콘텐츠 전문기업(매출150억) 프론트엔드개발자 채용   대졸↑  NaN  서울 서초구
# 2         리비바이오                      [리비바이오] 프론트엔드개발자  학력무관  NaN  서울 강남구
# 3          조베이스                       프론트엔드개발자 경력직 모집   대졸↑  NaN  서울 강남구
# 4          디카르고                              프론트엔드개발자  학력무관  NaN  서울 강남구
# ...         ...                                   ...   ...  ...     ...
# 1020     업템포글로벌            프론트엔드 개발 팀원 모집 [경력/글로벌 인재]  학력무관  NaN  서울 강남구
# 1021  스타일씨코퍼레이션                               백엔드 개발자  학력무관  NaN  서울 마포구
# 1022   스마트러닝코리아                             웹 풀스택 개발자   대졸↑  NaN  서울 강남구
# 1023  스타일씨코퍼레이션                   node.js 개발자 (3년 이상)  학력무관  NaN  서울 마포구
# 1024     도움이티에스  주니어 개발자 [C#/WEB] 인재를 모십니다. [파견근무 없음]  초대졸↑  NaN    서울전체
#
#                                                   공고 링크
# 0     https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 1     https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 2     https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 3     https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 4     https://www.saramin.co.kr/zf_user/jobs/relay/v...
# ...                                                 ...
# 1020  https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 1021  https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 1022  https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 1023  https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 1024  https://www.saramin.co.kr/zf_user/jobs/relay/v...
#
# [1025 rows x 6 columns]

# %%
import pandas as pd
from IPython.display import display

# 데이터 불러오기
df_saramin2 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/saramin_result2.csv')

# '경력' 열 추가 (빈 값으로 설정)
df_saramin2['경력'] = pd.NA

# 필요한 열만 선택
df_selected_saramin2 = df_saramin2[['회사명', '공고명', '학력', '경력', '지역', '공고 링크']]

# 데이터프레임 형태로 출력
display(df_selected_saramin2)

# 선택한 열로 새로운 파일 저장
df_selected_saramin2.to_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_saramin_result2.csv', index=False)
# Out:
#              회사명                                  공고명    학력   경력       지역  \
# 0     트랜스코스모스코리아     [여의도/샛강역] CX개발부 솔루션 웹개발자 채용 Mo1Y  초대졸↑  NaN  서울 영등포구
# 1         진코퍼레이션  2024-1차) java, jsp, Nexacro 웹개발자 채용  초대졸↑  NaN   서울 금천구
# 2           라톤테크                     JAVA/JSP 웹개발자 모집   대졸↑  NaN   서울 금천구
# 3        피엠그룹코리아                      신입 JAVA 웹개발자 모집  학력무관  NaN   서울 강남구
# 4         해오름인포텍           2024년 하반기 신입 웹개발자(JAVA) 채용  초대졸↑  NaN   서울 금천구
# ...          ...                                  ...   ...  ...      ...
# 1001   오픈엣지테크놀로지     [Web Service] Front-end Engineer  학력무관  NaN   서울 강남구
# 1002          엠로                    Cloud 인프라 아키텍쳐 담당   대졸↑  NaN     서울전체
# 1003          위펀    (주)위펀 - Frontend Engineer (React)  학력무관  NaN   서울 강남구
# 1004   비에이블컨설팅그룹  [버추얼휴먼 전문기업] 시니어 백엔드 개발자 (경력 7년 이상)   대졸↑  NaN   서울 마포구
# 1005      넛지헬스케어         [넛지헬스케어] 풀스택개발 산업기능요원 (병역특례)  학력무관  NaN   서울 강남구
#
#                                                   공고 링크
# 0     https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 1     https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 2     https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 3     https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 4     https://www.saramin.co.kr/zf_user/jobs/relay/v...
# ...                                                 ...
# 1001  https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 1002  https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 1003  https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 1004  https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 1005  https://www.saramin.co.kr/zf_user/jobs/relay/v...
#
# [1006 rows x 6 columns]

# %%
import pandas as pd

# 각각의 필터된 CSV 파일 불러오기
df_incruit = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_incruit_result.csv')
df_incruit2 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_incruit_result2.csv')
df_jobkorea1 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_jobkorea_result.csv')
df_jobkorea2 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_jobkorea_result2.csv')
df_jobkorea3 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_jobkorea_result3.csv')
df_saramin = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_saramin_result.csv')
df_saramin2 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_saramin_result2.csv')

# 데이터프레임들을 하나로 합치기
df_combined = pd.concat([df_incruit, df_jobkorea1, df_jobkorea2, df_jobkorea3, df_saramin, df_saramin2], ignore_index=True)

df_combined
# Out:
#                회사명                                  공고명    학력         경력  \
# 0     주식회사 더쇼소프트웨어                   게임 프론트엔드 개발자 채용 공고  학력무관      5~99년
# 1              시스루          웹 시스템 유지보수 프론트엔드/백엔드 개발자 채용  학력무관        3년↑
# 2            프리것버드                    프론트엔드 개발자 모집(팀장급)  학력무관        5년↑
# 3             비브이씨                    비브이씨 프론트엔드 개발자 모집  학력무관  신입/(연차무관)
# 4             딥세일즈                      프론트엔드개발자 (5년이상)  대졸이상        5년↑
# ...            ...                                  ...   ...        ...
# 7394     오픈엣지테크놀로지     [Web Service] Front-end Engineer  학력무관        NaN
# 7395            엠로                    Cloud 인프라 아키텍쳐 담당   대졸↑        NaN
# 7396            위펀    (주)위펀 - Frontend Engineer (React)  학력무관        NaN
# 7397     비에이블컨설팅그룹  [버추얼휴먼 전문기업] 시니어 백엔드 개발자 (경력 7년 이상)   대졸↑        NaN
# 7398        넛지헬스케어         [넛지헬스케어] 풀스택개발 산업기능요원 (병역특례)  학력무관        NaN
#
#           지역                                              공고 링크
# 0     서울>강남구  https://job.incruit.com/jobdb_info/jobpost.asp...
# 1     서울>용산구  https://job.incruit.com/jobdb_info/jobpost.asp...
# 2       서울 외  https://job.incruit.com/jobdb_info/jobpost.asp...
# 3     서울>마포구  https://job.incruit.com/jobdb_info/jobpost.asp...
# 4     서울>강남구  https://job.incruit.com/jobdb_info/jobpost.asp...
# ...      ...                                                ...
# 7394  서울 강남구  https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 7395    서울전체  https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 7396  서울 강남구  https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 7397  서울 마포구  https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 7398  서울 강남구  https://www.saramin.co.kr/zf_user/jobs/relay/v...
#
# [7399 rows x 6 columns]

# %%
# 각각의 필터된 CSV 파일 불러오기
df_incruit = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/incruit_result.csv')
df_incruit2 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/incruit_result2.csv')
df_jobkorea1 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/jobkorea_result.csv')
df_jobkorea2 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/jobkorea_result2.csv')
df_jobkorea3 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/jobkorea_result3.csv')
df_saramin = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/saramin_result.csv')
df_saramin2 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/saramin_result2.csv')

# 데이터프레임들을 하나로 합치기
df_combined = pd.concat([df_incruit, df_jobkorea1, df_jobkorea2, df_jobkorea3, df_saramin, df_saramin2], ignore_index=True)

# %%
import pandas as pd

# 각각의 필터된 CSV 파일 불러오기
df_incruit = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_incruit_result.csv')
df_incruit2 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_incruit_result2.csv')
df_jobkorea1 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_jobkorea_result.csv')
df_jobkorea2 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_jobkorea_result2.csv')
df_jobkorea3 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_jobkorea_result3.csv')
df_saramin = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_saramin_result.csv')
df_saramin2 = pd.read_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/filtered_saramin_result2.csv')

# 데이터프레임들을 하나로 합치기
df_combined = pd.concat([df_incruit, df_jobkorea1, df_jobkorea2, df_jobkorea3, df_saramin, df_saramin2], ignore_index=True)

# 회사명과 공고명에서 특정 문자열 제거
df_combined['회사명'] = df_combined['회사명'].replace({'㈜': '', '(주)': '', '(사)': ''}, regex=True)
df_combined['공고명'] = df_combined['공고명'].replace({'㈜': '', '(주)': '', '(사)': ''}, regex=True)

# 공고명과 회사명에서 특정 문자를 공백으로 대체
for char in ['[', ']', '(', ')', '/', ',']:
    df_combined['회사명'] = df_combined['회사명'].str.replace(char, ' ', regex=False)
    df_combined['공고명'] = df_combined['공고명'].str.replace(char, ' ', regex=False)

# 'F E'를 'FE'로 바꾸기
df_combined['회사명'] = df_combined['회사명'].str.replace('F E', 'FE', regex=False)
df_combined['공고명'] = df_combined['공고명'].str.replace('F E', 'FE', regex=False)

# 'B E'를 '백엔드'로 바꾸기
df_combined['회사명'] = df_combined['회사명'].str.replace('B E', '백엔드', regex=False)
df_combined['공고명'] = df_combined['공고명'].str.replace('B E', '백엔드', regex=False)

# '국비지원', '국비교육', '백엔드'가 포함된 행 제거
df_combined = df_combined[~df_combined['공고명'].str.contains('국비지원|국비교육|백엔드', na=False)]

# 특정 키워드가 포함된 공고명에서 해당 키워드를 제거
keywords_to_remove = [
    '경력 채용', '모집', '개발자 모집', '개발자 채용',
    '프론트엔드 개발자', '모집합니다', '운영', '채용공고', '개발', '경력', '개발자', '채용'
]

# 공고명에서 특정 키워드 제거
for keyword in keywords_to_remove:
    df_combined['공고명'] = df_combined['공고명'].str.replace(keyword, '', regex=False)

# 학력 정보를 수정하는 함수 정의
def update_education(row):
    if '대졸' in row['학력']:
        return '대졸↑'
    elif '초대졸' in row['학력']:
        return '초대졸↑'
    elif '고졸' in row['학력']:
        return '고졸↑'
    return row['학력']

# 학력 열 업데이트
df_combined['학력'] = df_combined.apply(update_education, axis=1)

# 회사명과 공고명으로 중복 제거, 하나는 남겨놓기
df_combined = df_combined.sort_values(by=['회사명', '공고명']).drop_duplicates(subset=['회사명', '공고명'], keep='first').reset_index(drop=True)

# 결과 확인
display(df_combined)

# 수정된 데이터를 새로운 파일로 저장
df_combined.to_csv('/content/drive/MyDrive/2024 머신 코스 - 1/크롤링/combined_job_results_updated.csv', index=False)
# Out:
# <ipython-input-73-a9e0a9fac015>:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_combined['공고명'] = df_combined['공고명'].str.replace(keyword, '', regex=False)
#                              회사명  \
# 0       한국디지털컨버전스협회 부설 방송정보국제교육원
# 1                     한국아이씨티기술협회
# 2                       환경책임보험업단
# 3                   국내최대 오픈마켓기업
# 4                   국내최대 오픈마켓기업
# ...                          ...
# 4693                    희림종합건축무소
# 4694                       희현아이티
# 4695                       히릿소프트
# 4696                       히릿소프트
# 4697                       히릿소프트
#
#                                                  공고명    학력     경력       지역  \
# 0      각 분야 직업훈련 강 구인 - 영상  모션그래픽  3D그래픽  유니티  언리얼 등   대졸↑  경력5년↑  서울 영등포구
# 1                         국비무료IT취업 자바파이썬 웹 빅데이터 인공지능  학력무관    NaN     서울전체
# 2                           환경책임보험업단 정보화업팀  계약직   공고   대졸↑  경력2년↑   서울 서초구
# 3                             국내최대오픈마켓기업  UX UI 디자이너   대졸↑  경력4년↑   서울 강남구
# 4               국내최대오픈마켓기업  규제대응 AML  FDS 등 시스템 FE 자   대졸↑  경력4년↑   서울 강남구
# ...                                              ...   ...    ...      ...
# 4693                    친환경건축 웹 기술제안서 CM현장 바이오에너지등    학력무관    NaN     서울전체
# 4694                                          자바 프론트  학력무관  경력7년↑   서울 송파구
# 4695   Front-end  vue.js  세계 최고의 노코드 플랫폼 팀에서 를 찾습니다.  학력무관  경력7년↑   서울 강남구
# 4696        안드로이드  세계 최고의 노코드 플랫폼 팀에서 안드로이드 자를 찾습니다.  학력무관  경력3년↑   서울 강남구
# 4697                   세계 최고의 노코드 팀 프론트엔드 vue.js  자   학력무관    NaN   서울 강남구
#
#                                                   공고 링크
# 0     https://www.jobkorea.co.kr/Recruit/GI_Read/454...
# 1     https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 2     https://www.jobkorea.co.kr/Recruit/GI_Read/455...
# 3     https://www.jobkorea.co.kr/Recruit/GI_Read/450...
# 4     https://www.jobkorea.co.kr/Recruit/GI_Read/451...
# ...                                                 ...
# 4693  https://www.saramin.co.kr/zf_user/jobs/relay/v...
# 4694  https://www.jobkorea.co.kr/Recruit/GI_Read/454...
# 4695  https://www.jobkorea.co.kr/Recruit/GI_Read/455...
# 4696  https://www.jobkorea.co.kr/Recruit/GI_Read/455...
# 4697  https://www.saramin.co.kr/zf_user/jobs/relay/v...
#
# [4698 rows x 6 columns]

# %%
# !apt-get install -y fonts-nanum
# !fc-cache -fv
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 49 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (8,254 kB/s)
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 123605 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
text = ' '.join(df_combined['공고명'].fillna(''))

# %%
font_path = '/content/drive/MyDrive/Colab Notebooks/font/NanumSquareR.ttf'
# 워드 클라우드 생성
wordcloud = WordCloud(font_path=font_path,width=800, height=400, background_color='white').generate(text)

# 워드 클라우드 시각화
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # 축을 숨김
plt.show()
